# %%
import pandas as pd

# %%
import unicodedata

def remove_non_utf8_chars(input_string):
    return ''.join(c for c in input_string if unicodedata.category(c)[0] != 'C')

# Ejemplo de uso
with open('./database/listadocronologico2017.csv') as archivo:
    print(archivo.read())
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /home/palios/universidad/intro_data_science/imt2022-project/src/database.ipynb Cell 2 line 8
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/palios/universidad/intro_data_science/imt2022-project/src/database.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> # Ejemplo de uso
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/palios/universidad/intro_data_science/imt2022-project/src/database.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> with open('./database/listadocronologico2017.csv') as archivo:
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/palios/universidad/intro_data_science/imt2022-project/src/database.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>     print(archivo.read())
#
# File /usr/lib/python3.10/codecs.py:322, in BufferedIncrementalDecoder.decode(self, input, final)
# ...

# %%
bio_equivalente = pd.read_csv('./database/listadocronologico2017.csv')
venta_directa = pd.read_csv('./database/ventas.csv', encoding='ISO-8859-1')
venta_directa
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /home/palios/universidad/intro_data_science/imt2022-project/src/database.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/palios/universidad/intro_data_science/imt2022-project/src/database.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> bio_equivalente = pd.read_csv('./database/listadocronologico2017.csv')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/palios/universidad/intro_data_science/imt2022-project/src/database.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> venta_directa = pd.read_csv('./database/ventas.csv', encoding='ISO-8859-1')
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/palios/universidad/intro_data_science/imt2022-project/src/database.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> venta_directa
#
# ...

# %%
venta_directa
