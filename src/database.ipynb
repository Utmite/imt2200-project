# %%
import pandas as pd

# %%
venta_directa = pd.read_csv('./database/ventas.csv')
venta_directa
# Out:
#        _id Ndeg Registro                                    Nombre Producto  \
# 0        1     B-1000/10               SPERTI PREPARATION H UNGÜENTO TÓPICO
# 1        2     B-1007/10  INFLUVAC VACUNA ANTI - INFLUENZA SUSPENSIÓN IN...
# 2        3     B-1158/11                         BACITOPIC UNGÜENTO DÉRMICO
# 3        4     B-2171/11      FLUAD VACUNA ANTIGRIPAL SUSPENSIÓN INYECTABLE
# 4        5     B-2173/11  GC-FLU VACUNA ANTIINFLUENZA INACTIVADA, FRACCI...
# ...    ...           ...                                                ...
# 2423  2424       N-81/11                    CHISANDRA COMPUESTA COMPRIMIDOS
# 2424  2425       N-84/11                           ARMONYL CÁPSULAS BLANDAS
# 2425  2426       N-85/11         ARMONYL COMPUESTO SOLUCIÓN ORAL PARA GOTAS
# 2426  2427       N-86/11                 FIBRASOL SABOR A NARANJA POLVO 68%
# 2427  2428       N-92/11  ARMONYL SIN CRATAEGUS CON MANZANILLA CÁPSULAS ...
#
#                     Razon Social Titular Condicion Venta
# ...

# %%
venta_directa = pd.read_csv('./database/ventas.csv')
venta_directa
# Out:
#        _id Ndeg Registro                                    Nombre Producto  \
# 0        1     B-1000/10               SPERTI PREPARATION H UNGÜENTO TÓPICO
# 1        2     B-1007/10  INFLUVAC VACUNA ANTI - INFLUENZA SUSPENSIÓN IN...
# 2        3     B-1158/11                         BACITOPIC UNGÜENTO DÉRMICO
# 3        4     B-2171/11      FLUAD VACUNA ANTIGRIPAL SUSPENSIÓN INYECTABLE
# 4        5     B-2173/11  GC-FLU VACUNA ANTIINFLUENZA INACTIVADA, FRACCI...
# ...    ...           ...                                                ...
# 2423  2424       N-81/11                    CHISANDRA COMPUESTA COMPRIMIDOS
# 2424  2425       N-84/11                           ARMONYL CÁPSULAS BLANDAS
# 2425  2426       N-85/11         ARMONYL COMPUESTO SOLUCIÓN ORAL PARA GOTAS
# 2426  2427       N-86/11                 FIBRASOL SABOR A NARANJA POLVO 68%
# 2427  2428       N-92/11  ARMONYL SIN CRATAEGUS CON MANZANILLA CÁPSULAS ...
#
#                     Razon Social Titular Condicion Venta
# ...

# %%
from typing import List

with open("./database/cronologico.csv") as archivo:
    lineas: List[str] = archivo.readlines()


filas = [dato.strip().split(';') for dato in lineas]
columnas = filas[3]

del filas[0:4]

df = pd.DataFrame(filas, columns=columnas)

# Mostrar el DataFrame
df
# Out:
#         N° Principio Activo                                       Producto   \
# 0        1      PREGABALINA                      PLENICA 75 CÁPSULAS 75 mg
# 1        2      PREGABALINA                     PLENICA 150 CÁPSULAS 150 mg
# 2        3    ISOTRETINOÍNA                   ORALNE CÁPSULAS BLANDAS 10 mg
# 3        4    ISOTRETINOÍNA                   ORALNE CÁPSULAS BLANDAS 20 mg
# 4        5    ISOTRETINOÍNA    ORALNE CÁPSULAS BLANDAS 5 mg (ISOTRETINOÍNA)
# ...    ...              ...                                             ...
# 1550  1551        ZOPICLONA        ZOPICLONA COMPRIMIDOS RECUBIERTOS 7,5 mg
# 1551  1552       FLUCONAZOL                      FLUCONAZOL CÁPSULAS 150 mg
# 1552  1553      LAMOTRIGINA      TRIGILAB COMPRIMIDOS  200 mg (LAMOTRIGINA)
# 1553  1554        NAPROXENO  FLOGOTONE FORTE COMPRIMIDOS RECUBIERTOS 550 mg
# 1554  1555   CLARITROMICINA              MUS COMPRIMIDOS RECUBIERTOS 500 mg
#
# ...
