# %% [markdown]
# # Proyecto IMT2200 Grupo11
# ## Integrantes:
# - Benjamin Vasquez

# %% [markdown]
# ## Datos Bases Para todas las preguntas

# %%
#Librerias a usar
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd

# %%
df_censo = pd.read_csv('../database/Cantidad-de-Personas-por-Sexo-y-Edad.csv', sep=";")
df_farmacias = pd.read_csv("../database/2.-Farmacias-Chile-07.2023.csv", sep=";", encoding="utf-8")
df_hospitales = pd.read_excel("../database/Establecimientos_ChileDEIS_MINSAL 03-11-2023.xlsx", sheet_name="Establecimientos Vigentes")

# %%
def modificar_nombre_columna(nombre: str):
    nombre = nombre.strip()  
    nombre = nombre.lower() 
    nombre = nombre.replace(" ", "_")
    nombre = nombre.replace("\xa0", "_")
    return nombre

nuevos_nombres = {columna: modificar_nombre_columna(columna) for columna in df_censo.columns}
df_censo.rename(columns=nuevos_nombres, inplace=True)
df_censo.columns

df_censo["código_región"] = pd.to_numeric(df_censo["código_región"], errors="coerce")
df_censo["código_provincia"] = pd.to_numeric(df_censo["código_provincia"], errors="coerce")
df_censo["código_comuna"] = pd.to_numeric(df_censo["código_comuna"], errors="coerce")
df_censo["edad"] = df_censo["edad"].astype("category")
df_censo["hombres"] = df_censo["hombres"].str.replace(".", "").astype("int")
df_censo["mujeres"] = df_censo["mujeres"].str.replace(".", "").astype("int")
df_censo["total"] = df_censo["total"].str.replace(".", "").astype("int")
# Out:
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\3676604115.py:16: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_censo["hombres"] = df_censo["hombres"].str.replace(".", "").astype("int")
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\3676604115.py:17: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_censo["mujeres"] = df_censo["mujeres"].str.replace(".", "").astype("int")
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\3676604115.py:18: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df_censo["total"] = df_censo["total"].str.replace(".", "").astype("int")

# %%
df_hospitales.columns = df_hospitales.loc[0,:]
df_hospitales.drop(0, inplace=True)
df_hospitales.drop(columns=["Código Antiguo ", "Código  Madre Antiguo", "Código Madre Nuevo", "Código  Madre Antiguo", "Fecha de Incorporación a la base o cambios", "Teléfono", "Fecha Inicio Funcionamiento", "Vía", "Certificación ", "Número", "Dirección", "Clasificcion Tipo de SAPU", "Tipo Establecimiento (Unidad)", "Dependencia Administrativa"], inplace=True)

# %%
df_hospitales.replace(["No Aplica", "Pendiente", "Completar", "No Aplica", "Por confirmar", "no Aplica", "Pendiente", "no aplica", "No Aplica"], np.NaN, inplace=True)

df_hospitales["Código Vigente"] = df_hospitales["Código Vigente"].astype("int")

df_hospitales["Código Región"] = df_hospitales["Código Región"].astype("int")

df_hospitales["Código Dependencia Jerárquica (SEREMI / Servicio de Salud)"] = df_hospitales["Código Dependencia Jerárquica (SEREMI / Servicio de Salud)"].astype("float")

df_hospitales["Pertenencia al SNSS"] = df_hospitales["Pertenencia al SNSS"].map(lambda x: x == 'Perteneciente' or x == True)
df_hospitales["Pertenencia al SNSS"] = df_hospitales["Pertenencia al SNSS"].astype("bool")

df_hospitales["Nivel de Atención"] = df_hospitales["Nivel de Atención"].astype("category")

df_hospitales["Tiene Servicio de Urgencia"] = df_hospitales["Tiene Servicio de Urgencia"].map(lambda x: x == 'SI' or x == True)
df_hospitales["Tiene Servicio de Urgencia"] = df_hospitales["Tiene Servicio de Urgencia"].astype("bool")
df_hospitales["Tipo de Urgencia "] = df_hospitales["Tipo de Urgencia "].astype("category")
df_hospitales["Tipo de Prestador Sistema de Salud"] = df_hospitales["Tipo de Prestador Sistema de Salud"].astype("category")

df_hospitales["Nivel de Complejidad"] = df_hospitales["Nivel de Complejidad"].astype("category")
df_hospitales["Tipo de Atención "] = df_hospitales["Tipo de Atención "].astype("category")

# %%
df_hospitales = df_hospitales[df_hospitales['Estado de Funcionamiento'].str.contains("Vigente", case=False, na=False)]
df_hospitales.drop(columns="Estado de Funcionamiento", inplace=True)

# %%
nuevos_nombres = {columna: modificar_nombre_columna(columna) for columna in df_hospitales.columns}
df_hospitales.rename(columns=nuevos_nombres, inplace=True)
df_hospitales.rename(columns={"latitud______[grados_decimales]": "latitud", "longitud_[grados_decimales]":"longitud"}, inplace=True)
df_hospitales["código_región"] = df_hospitales["código_región"].astype("int")
df_hospitales["código_comuna"] = df_hospitales["código_comuna"].astype("int")
df_hospitales["nombre_comuna"] = df_hospitales["nombre_comuna"].str.upper()
df_hospitales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4525 entries, 1 to 4526
# Data columns (total 18 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   código_vigente                                              4525 non-null   int32
#  1   código_región                                               4525 non-null   int32
#  2   nombre_región                                               4525 non-null   object
#  3   código_dependencia_jerárquica_(seremi_/_servicio_de_salud)  4482 non-null   float64
#  4   nombre_dependencia_jerárquica_(seremi_/_servicio_de_salud)  4483 non-null   object
#  5   pertenencia_al_snss                                         4525 non-null   bool
#  6   ámbito_de_funcionamiento                                    4525 non-null   object
#  7   nombre_oficial                                              4525 non-null   object
#  8   nivel_de_atención                                           3676 non-null   category
#  9   código_comuna                                               4525 non-null   int32
#  10  nombre_comuna                                               4525 non-null   object
#  11  tiene_servicio_de_urgencia                                  4525 non-null   bool
#  12  tipo_de_urgencia                                            742 non-null    category
#  13  latitud                                                     4450 non-null   float64
#  14  longitud                                                    4448 non-null   float64
#  15  tipo_de_prestador_sistema_de_salud                          4513 non-null   category
#  16  nivel_de_complejidad                                        3898 non-null   category
#  17  tipo_de_atención                                            4117 non-null   category
# dtypes: bool(2), category(5), float64(3), int32(3), object(5)
# memory usage: 403.2+ KB

# %%
comunas_ñuble = {16109: 'YUNGAY',
 16105: 'PEMUCO',
 16104: 'EL CARMEN',
 16107: 'QUILLÓN',
 16108: 'SAN IGNACIO',
 16106: 'PINTO',
 16102: 'BULNES',
 16302: 'COIHUECO',
 16103: 'CHILLÁN VIEJO',
 16206: 'RÁNQUIL',
 16304: 'SAN FABIÁN',
 16101: 'CHILLÁN',
 16205: 'PORTEZUELO',
 16203: 'COELEMU',
 16305: 'SAN NICOLÁS',
 16301: 'SAN CARLOS',
 16207: 'TREGUACO',
 16204: 'NINHUE',
 16303: 'ÑIQUÉN',
 16201: 'QUIRIHUE',
 16202: 'COBQUECURA'}
comunas_ñuble = {v: k for k, v in comunas_ñuble.items()}


provincias_ñuble = {
    161: "DIGUILLÍN",
    162: "ITATA",
    163: "PUNILLA"
}

# %%
d = df_censo[df_censo["nombre_provincia"].str.contains("ÑUBLE")]
d["nombre_comuna"] = d["nombre_comuna"].str.replace(" *", "")
d
d["código_comuna"] = d["nombre_comuna"].map(comunas_ñuble).astype("string")
d["nombre_región"] = "ÑUBLE"
d["código_región"] = 16
d["código_provincia"] = d["código_comuna"].str.slice(0,3)
d["código_provincia"] = d["código_provincia"].astype("int")
d["nombre_provincia"] = d["código_provincia"].map(provincias_ñuble)
# Out:
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\4203659101.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   d["nombre_comuna"] = d["nombre_comuna"].str.replace(" *", "")
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\4203659101.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["nombre_comuna"] = d["nombre_comuna"].str.replace(" *", "")
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\4203659101.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["código_comuna"] = d["nombre_comuna"].map(comunas_ñuble).astype("string")
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\4203659101.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["nombre_región"] = "ÑUBLE"
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\4203659101.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["código_región"] = 16
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\4203659101.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d["código_provincia"] = d["código_comuna"].str.slice(0,3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 8>()
#       6 d["código_región"] = 16
#       7 d["código_provincia"] = d["código_comuna"].str.slice(0,3)
# ----> 8 d["código_provincia"] = d["código_provincia"].astype("int")
#       9 d["nombre_provincia"] = d["código_provincia"].map(provincias_ñuble)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\generic.py:5920, in NDFrame.astype(self, dtype, copy, errors)
#    5913     results = [
#    5914         self.iloc[:, i].astype(dtype, copy=copy)
#    5915         for i in range(len(self.columns))
#    5916     ]
#    5918 else:
#    5919     # else, only a single dtype is given
# -> 5920     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5921     return self._constructor(new_data).__finalize__(self, method="astype")
#    5923 # GH 33113: handle empty frame or series
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
#     418 def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419     return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\internals\blocks.py:580, in Block.astype(self, dtype, copy, errors)
#     562 """
#     563 Coerce to the new dtype.
#     564
#    (...)
#     576 Block
#     577 """
#     578 values = self.values
# --> 580 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     582 new_values = maybe_coerce_values(new_values)
#     583 newb = self.make_block(new_values)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\dtypes\cast.py:1292, in astype_array_safe(values, dtype, copy, errors)
#    1289     dtype = dtype.numpy_dtype
#    1291 try:
# -> 1292     new_values = astype_array(values, dtype, copy=copy)
#    1293 except (ValueError, TypeError):
#    1294     # e.g. astype_nansafe can fail on object-dtype of strings
#    1295     #  trying to convert to float
#    1296     if errors == "ignore":
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\dtypes\cast.py:1234, in astype_array(values, dtype, copy)
#    1230     return values
#    1232 if not isinstance(values, np.ndarray):
#    1233     # i.e. ExtensionArray
# -> 1234     values = values.astype(dtype, copy=copy)
#    1236 else:
#    1237     values = astype_nansafe(values, dtype, copy=copy)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\arrays\string_.py:446, in StringArray.astype(self, dtype, copy)
#     443     values[mask] = np.nan
#     444     return values
# --> 446 return super().astype(dtype, copy)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\arrays\base.py:584, in ExtensionArray.astype(self, dtype, copy)
#     581     cls = dtype.construct_array_type()
#     582     return cls._from_sequence(self, dtype=dtype, copy=copy)
# --> 584 return np.array(self, dtype=dtype, copy=copy)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\arrays\numpy_.py:129, in PandasArray.__array__(self, dtype)
#     128 def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# --> 129     return np.asarray(self._ndarray, dtype=dtype)
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NAType'

# %%
df_censo.drop(df_censo[df_censo["nombre_provincia"].str.contains("ÑUBLE")].index, inplace=True)

# %%
df_censo = pd.concat([df_censo, d], ignore_index=True)
df_censo

# %%
df_censo.sort_values(by="orden", inplace=True)

# %%
codigo_comuna_a_provincia = dict(zip(df_censo['código_comuna'], df_censo['código_provincia']))
codigo_comuna_a_provincia = {int(comuna): int(provincia) for comuna, provincia in codigo_comuna_a_provincia.items() if not pd.isna(provincia)}

codigo_comuna_a_region = dict(zip(df_censo['código_comuna'], df_censo['código_región']))
codigo_comuna_a_region = {int(comuna): int(region) for comuna, region in codigo_comuna_a_region.items() if not pd.isna(region)}

# %%
df_hospitales.loc[:, "código_provincia"] = df_hospitales["código_comuna"].map(codigo_comuna_a_provincia)
df_hospitales["código_provincia"] = df_hospitales["código_provincia"].astype("int")

# %%
nuevos_nombres = {columna: modificar_nombre_columna(columna) for columna in df_farmacias.columns}
df_farmacias.rename(columns=nuevos_nombres, inplace=True)

# %%
df_farmacias.drop(columns=["empresa_farmacéutica", "empresa_rut", "empresa_razón_social", "nro_resolución_apertura", "número", "dirección", "fecha_res."], inplace=True)

# %%
df_farmacias.replace(["SIN RECETARIO", "NOSELECCIONADO"], np.nan)

df_farmacias["tipo"] = df_farmacias["tipo"].astype("category")

df_farmacias["latitud"] = df_farmacias["latitud"].str.replace(",",".").str.rstrip(".").str.rstrip("°")

df_farmacias["longitud"] = df_farmacias["longitud"].str.replace(",",".").str.rstrip(".").str.rstrip("°")

df_farmacias["tipo_recetario"] = df_farmacias["tipo_recetario"].astype("category")

df_farmacias["alopática"] = df_farmacias["alopática"].map(lambda x: x == 'SI' or x == True)
df_farmacias["alopática"] = df_farmacias["alopática"].astype("bool")

df_farmacias["homeopática"] = df_farmacias["homeopática"].map(lambda x: x == 'SI' or x == True)
df_farmacias["homeopática"] = df_farmacias["homeopática"].astype("bool")

# %%
# %%
df_farmacias.loc[:,"código_comuna"] = df_farmacias.loc[:,"comuna"].str.replace("Ñ", "N").map(nombre_comuna_a_codigo_comuna)
df_farmacias.loc[:,"código_provincia"] = df_farmacias.loc[:,"código_comuna"].map(codigo_comuna_a_provincia)
df_farmacias.loc[:,"código_región"] = df_farmacias.loc[:,"código_comuna"].map(codigo_comuna_a_region)

df_farmacias.dropna(subset="comuna", inplace=True)
df_farmacias["código_comuna"] = df_farmacias["código_comuna"].astype("int")

# %%
df_farmacias["latitud"] = pd.to_numeric(df_farmacias['latitud'], errors='coerce')
df_farmacias["longitud"] = pd.to_numeric(df_farmacias['longitud'], errors='coerce')

# %%
df_farmacias.info()

# %%
df_hospitales

# %%
df_farmacias

# %% [markdown]
# # Pregunta 4
# ### ¿Cuál es la distancia promedio entre los centros de salud y zonas pobladas?

# %%
#abrimos el shapefile de areas pobladas obtemido de "https://www.bcn.cl/obtienearchivo?id=repositorio/10221/10405/2/Areas_Pobladas.zip"
areas_pobladas = gpd.read_file('../database/DatosGeograficos/Areas_Pobladas.shp', engine="fiona", crs='')
areas_pobladas['geometry'] = areas_pobladas['geometry'].to_crs(5360)

# %% [markdown]
# Este archivo de areas pobladas proviene de la biblioteca del congreso nacional de chile y contiene la figura de cada una de las areas que se consideran pobladas
# en el territorio chileno, esto no contien lo que el INE clasifica como caserios, la division mas pequeña que se maneja en este archivo es "aldea". Justamente estas 'aldeas' que estan en el archivo
# son los lugares donde nos queremos concentrar para lograr encontrar que tan lejos estan de centros de salud de baja, media y alta complejidad.
#
# A continuacion se detalla el limpiamiento de los datos y una breve exploración ya que al trabajar con datos geoespaciales medidas de exploración como promedio y desviación estandar nos son de poca utilidad.
# Asumiremos el centroide de cada localidad como el punto de referencia para medir distancia hacia los establecimientos de salud, mas adelante iremos descartando localidades que tengan centros de salud dentro de ellas segun necesitemos en cada caso.

# %%
#calculamos el centroide de cada figura
areas_pobladas["centroide"] = areas_pobladas["geometry"].centroid
# Out:
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\1046282378.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   areas_pobladas["centroide"] = areas_pobladas["geometry"].centroid

# %%
#separamos la latitud y longitud en dos coluumnas para poder hacer masfacilmente la resta entre
#los hospitales y las areas pobladas ya que el dataframe de los hospitales contiene la ubicacion en dos columnas separadas

areas_pobladas['lat'] = areas_pobladas.centroide.y
areas_pobladas['long'] = areas_pobladas.centroide.x

# %% [markdown]
# Ahora que tenemos lo datos necesarios para contestar la pregunta 4 creados, procederos a limpiar la base de datos de hospitales.
# Primero eliminaremos las filas que no tengan datos en latitud o longitud ya que sin las coordenadas no se podra responder la pregunta.

# %%
df_hospitales_P4 = df_hospitales.dropna(subset=['latitud', 'longitud', 'nivel_de_complejidad'])

# %%
#pasamos el dataframe de hospitales a un geodaframe para poder hacer uso de los metodos que se incluyen en geopandas
gdf_hospitales = gpd.GeoDataFrame(
    df_hospitales_P4, geometry=gpd.points_from_xy(df_hospitales_P4.longitud, df_hospitales_P4.latitud), crs="EPSG:5360"
)

# %%
#creamos un diccionario que cotiene los hospitales de cada región, y estos ademas separados por complejidad.
centros_de_salud_por_region = {}
for region in gdf_hospitales.código_región.unique():
    centros_de_salud_por_complejidad = {}
    for complejidad in gdf_hospitales[gdf_hospitales['código_región'] == region].nivel_de_complejidad.unique():
        mask = ((gdf_hospitales['código_región'] == region) & (gdf_hospitales['nivel_de_complejidad'] == complejidad))
        centros_de_salud_por_complejidad[complejidad] = gdf_hospitales[mask]
    centros_de_salud_por_region[region] = centros_de_salud_por_complejidad

# %%
comunas = gpd.read_file('../database/DatosGeograficos/comunas.shp', engine="fiona", crs='')
comunas.rename(columns={'codregion': 'código_región', 'Region': 'nombre_región', 'Comuna': 'comuna'}, inplace=True)

# %%
areas_pobladas
# Out:
#      objectid       comuna    st_area_sh    st_length_         Localidad  \
# 0           1        Arica  2.516710e+07  35460.172620             Arica
# 1          16      Copiapó  2.678666e+07  76928.884528           Copiapó
# 2          17     Chañaral  3.337566e+06  12855.260828          Chañaral
# 3         147        Cunco  6.287806e+05   5378.380984        Hortensias
# 4         269    Peralillo  1.498707e+06   6526.575192         Peralillo
# ..        ...          ...           ...           ...               ...
# 647     31671         Lebu  1.621438e+06  17533.680760  Villa Santa Rosa
# 648       150  Los Muermos  3.393823e+06  14631.447042       Los Muermos
# 649     31672  Los Muermos  8.574474e+05   4883.610021           Cañitas
# 650     31673       Lumaco  3.988474e+05   3650.913819    Pichipellahuén
# 651       118       Lumaco  1.489756e+06   6226.381398   Capitan Pastene
#
#     Entidad                                           geometry  \
# 0    Ciudad  POLYGON ((-70.27828 -18.48655, -70.27743 -18.4...
# 1    Ciudad  POLYGON ((-70.35781 -27.34742, -70.35592 -27.3...
# 2    Ciudad  POLYGON ((-70.61893 -26.33908, -70.61834 -26.3...
# 3     Aldea  POLYGON ((-72.15989 -38.94468, -72.16037 -38.9...
# 4    Pueblo  POLYGON ((-71.48222 -34.47253, -71.48127 -34.4...
# ..      ...                                                ...
# 647   Aldea  POLYGON ((-73.57917 -37.64852, -73.57892 -37.6...
# 648  Pueblo  POLYGON ((-73.45588 -41.39657, -73.45598 -41.3...
# 649   Aldea  POLYGON ((-73.45008 -41.29922, -73.45025 -41.3...
# 650   Aldea  POLYGON ((-72.99697 -38.32075, -72.99656 -38.3...
# 651  Pueblo  POLYGON ((-72.98748 -38.19662, -72.98751 -38.1...
#
#                        centroide        lat       long
# 0    POINT (-70.29609 -18.47113) -18.471127 -70.296089
# 1    POINT (-70.32075 -27.37346) -27.373457 -70.320753
# 2    POINT (-70.61458 -26.34213) -26.342126 -70.614584
# 3    POINT (-72.15464 -38.94152) -38.941520 -72.154644
# 4    POINT (-71.47925 -34.47825) -34.478246 -71.479253
# ..                           ...        ...        ...
# 647  POINT (-73.61424 -37.64528) -37.645285 -73.614242
# 648  POINT (-73.46234 -41.39689) -41.396894 -73.462340
# 649  POINT (-73.45456 -41.30234) -41.302344 -73.454562
# 650  POINT (-72.99950 -38.32375) -38.323748 -72.999497
# 651  POINT (-72.99213 -38.19463) -38.194631 -72.992134
#
# [652 rows x 10 columns]

# %%
areas_pobladas_expandido = pd.merge(areas_pobladas, comunas, how='outer', on='comuna')

# %%
#comunas del archivo de areas pobladas que no fueron asignadas a comunas de comunas. AKA 'comunas sin región'
for name in areas_pobladas_expandido[areas_pobladas_expandido['nombre_región'].isna()]['comuna'].unique():
    print(name)
# Out:
# Tirua
# Quillaco
# Requinoa
# Mulchen
# San Nicolas
# Santa Barbara
# Dichato
# Chillan Viejo
# Chillan
# Mellipeuco
# Traiguen
# Puren
# Teodoro Schimidt
# Tolten
# Padre de Las Casas
# Curacautin
# Quellon
# Tiltíl
# Chaiten
# Mafil
# PUCHUNCAVI
# Los Ángeles
# Quilpue
# Olmue
# La Calera
# Cabo de HOrnos
# Machali
# Maríe Elena
# Longavi
# Licanten
# Río Ibañez
# Curacavi
# PUENTE ALTO
# Ranquíl
# Las Cruces
# O´Higgins
# Maullin
# Futaleufu
# Curaco
# Ranco
# Rio Bueno
# San Juan de La Costa
# Coihaique

# %%
#nombres correctos para que merge funcione con todas las comunas que tienen areas pobladas
nuevos_nombres = {'Tirua': 'Tirúa',
                  'Quillaco': 'Quilaco',
                  'Requinoa': 'Requínoa',
                  'Mulchen': 'Mulchén',
                  'Santa Barbara': 'Santa Bárbara',
                  'Puren': 'Purén',
                  'Tolten': 'Toltén',
                  'Padre de Las Casas': 'Padre Las Casas',
                  'Quellon': 'Quellón',
                  'Chaiten': 'Chaitén',
                  'Mafil': 'Máfil',
                  'PUCHUNCAVI': 'Puchuncaví',
                  'Quilpue ': 'Quilpué',
                  'La Calera': 'Calera',
                  'Cabo de HOrnos': 'Cabo de Hornos',
                  'Machali': 'Machalí',
                  'Maríe Elena': 'María Elena',
                  'Longavi': 'Longaví',
                  'Licanten': 'Licantén',
                  'Futaleufu': 'Futaleufú',
                  'Río Ibañez': 'Río Ibáñez',
                  'Curacavi': 'Curacaví',
                  'PUENTE ALTO': 'Puente Alto',
                  'Maullin': 'Maullín',
                  'Rio Bueno': 'Río Bueno',
                  'Coihaique': 'Coyhaique',
                  'Chillan Viejo': 'Chillán Viejo',
                  'Chillan': 'Chillán',
                  'Mellipeuco': 'Melipeuco',
                  'Curacautin': 'Curacautín',
                  'Traiguen': 'Traiguén',
                  'San Nicolas': 'San Nicolás',
                  'Teodoro Schimidt': 'Teodoro Schmidt',
                  'Las Cruces': 'El Tabo',
                  'Dichato': 'Tomé',
                  'Ranco': 'Lago Ranco',
                  'San Juan de La Costa': 'San Juan de la Costa',
                  'Los Ángeles': 'Los Angeles',
                  'Tiltíl': 'Tiltil',
                  'Curaco': 'Curaco de Vélez',
                  'O´Higgins': 'O\'Higgins',
                  'Olmue': 'Olmué',
                  'Ranquíl': 'Ranquil'}

# %%
#Ahora arreglaremos los nombres de las comunas que quedaron sin region, en el dataframe ed areas pobladas
areas_pobladas['comuna'] = areas_pobladas['comuna'].map(nuevos_nombres).fillna(areas_pobladas['comuna'])

# %%
areas_pobladas_expandido = pd.merge(areas_pobladas, comunas, how='outer', on='comuna')

# %%
areas_pobladas_expandido[areas_pobladas_expandido['nombre_región'].isna()]#Por alguna razón quilpué no se mapea bien, este caso lo asignaremos a mano.
# Out:
#      objectid_x   comuna  st_area_sh_x  st_length__x Localidad Entidad  \
# 349       235.0  Quilpue  3.538364e+07  68554.565505   Quilpue  Ciudad
#
#                                             geometry_x  \
# 349  MULTIPOLYGON (((-71.47843 -33.03070, -71.47828...
#
#                        centroide        lat       long  ...  shape_leng  \
# 349  POINT (-71.43234 -33.05056) -33.050558 -71.432341  ...         NaN
#
#      dis_elec  cir_sena  cod_comuna  código_región  st_area_sh_y  \
# 349       NaN       NaN         NaN            NaN           NaN
#
#      st_length__y  nombre_región Provincia geometry_y
# 349           NaN            NaN       NaN       None
#
# [1 rows x 21 columns]

# %%
#visualizamos los datos que faltan para qulpué
comunas[comunas['Provincia']=='Marga Marga']
# Out:
#      objectid     shape_leng  dis_elec  cir_sena  cod_comuna  código_región  \
# 69        181   69802.239962         6         6        5803              5
# 75        202   51418.528210         6         6        5804              5
# 246       179  121171.627118         6         6        5802              5
# 324       199  163202.154847         6         6        5801              5
#
#        st_area_sh     st_length_         nombre_región         comuna  \
# 69   3.288190e+08   83356.662942  Región de Valparaíso          Olmué
# 75   1.361912e+08   61466.831272  Región de Valparaíso  Villa Alemana
# 246  4.199598e+08  141344.715580  Región de Valparaíso        Limache
# 324  7.674004e+08  195680.328671  Región de Valparaíso        Quilpué
#
#        Provincia                                           geometry
# 69   Marga Marga  POLYGON ((-7916865.301 -3889409.945, -7916800....
# 75   Marga Marga  POLYGON ((-7948030.490 -3901449.640, -7948029....
# 246  Marga Marga  POLYGON ((-7952560.080 -3885023.296, -7952465....
# 324  Marga Marga  POLYGON ((-7951619.966 -3895596.503, -7951558....

# %%
#asignamos manualmente los datos que van en las columnas que flataban despues del merge
areas_pobladas_expandido.at[349,'nombre_región'] = 'Región de Valparaíso'
areas_pobladas_expandido.at[349,'código_región'] = 5

# %%
areas_pobladas_expandido[areas_pobladas_expandido['nombre_región'].isna()]#todas las comunas en el merge ahora estan asignadas correctamente
# Out:
# Empty GeoDataFrame
# Columns: [objectid_x, comuna, st_area_sh_x, st_length__x, Localidad, Entidad, geometry_x, centroide, lat, long, objectid_y, shape_leng, dis_elec, cir_sena, cod_comuna, código_región, st_area_sh_y, st_length__y, nombre_región, Provincia, geometry_y]
# Index: []
#
# [0 rows x 21 columns]

# %%
comunas[comunas['comuna']=='Las Condes']
# Out:
#      objectid    shape_leng  dis_elec  cir_sena  cod_comuna  código_región  \
# 156       315  51230.563241        11         7       13114             13
#
#        st_area_sh    st_length_                     nombre_región      comuna  \
# 156  1.416658e+08  61618.090148  Región Metropolitana de Santiago  Las Condes
#
#     Provincia                                           geometry
# 156  Santiago  POLYGON ((-7851625.483 -3946140.988, -7851625....

# %%
#Guardamos los datos de las areas pobladas por región
areas_pobladas_por_region = {}
for region in areas_pobladas_expandido.código_región.unique():
    areas_pobladas_por_region[int(region)] = areas_pobladas_expandido[areas_pobladas_expandido['código_región']==region]

# %% [markdown]
# Ahora que tenemos dos diccionarios, uno de hospitaels y otro de areas pobladas por región procederemos a usar clustering por densidad para buscar en cada región cuales areas pobladas quedan como puntoscde ruido, lo que correspondería a areas pobladas que estan mas lejos de lo óptimo a un cesntro de salud. Adicionalmente se haran 3 modelos para cada región donde se visualizaran los clusters usando centros de complejidad baja, media y alta.

# %%
import googlemaps, json
from datetime import datetime

key = 'AIzaSyDfwV9Yb-79WBNCFCnMbpwetxRuUaFYbD4'

gmaps = googlemaps.Client(key=key)

# %%
origin = list(zip(areas_pobladas_por_region[13]['lat'], areas_pobladas_por_region[13]['long']))
destination = list(zip(centros_de_salud_por_region[13]['Alta Complejidad']['latitud'], centros_de_salud_por_region[13]['Alta Complejidad']['longitud']))

# %%
full_duration_matrix = []

# Iterate through each combination of origin and destination, and make API requests
for origin_location in origin:
    row_duration = []
    for destination_location in destination:
        # Create lists of strings in the format 'latitude,longitude' for each pair
        origin_str = f'{origin_location[0]},{origin_location[1]}'
        destination_str = f'{destination_location[0]},{destination_location[1]}'

        try:
            # Use the distance_matrix method to get the distance matrix for the current pair
            result = gmaps.distance_matrix([origin_str], [destination_str], mode='driving', units='metric')

            # Check for errors in the API response
            if result['status'] == 'OK':
                # Extract the duration from the result (in seconds)
                duration_value = result['rows'][0]['elements'][0]['duration']['value']
                
                # Append the duration to the row duration list
                row_duration.append(duration_value)
            else:
                print(f"Error in API response: {result['status']}")
                if 'error_message' in result:
                    print(f"Error message: {result['error_message']}")

        except googlemaps.exceptions.ApiError as e:
            print(f"Error making API request: {e}")

    # Append the row duration list to the full duration matrix
    full_duration_matrix.append(row_duration)

# Print the full duration matrix
for row in full_duration_matrix:
    print(row)
# Out:
# [3341, 1238, 1361, 1652, 1186, 1248, 1361, 1244, 1521, 1298, 763, 673, 591, 399, 482, 1453, 1108, 1088, 948, 1663, 913, 623, 632, 687, 596, 739, 880, 981, 830, 322, 852, 686, 705, 1018, 617, 546, 1792, 666, 426, 882, 881, 1533, 687, 675, 738, 623, 1672, 1343, 933, 1044, 1042, 1027, 974, 1095]
# [3246, 1617, 1740, 1977, 1511, 1573, 1677, 1737, 1284, 1623, 1392, 1301, 1220, 1028, 1379, 1778, 952, 1158, 985, 1912, 1806, 1380, 1385, 1237, 1341, 1483, 1464, 1449, 1573, 835, 1404, 1155, 1174, 1354, 1086, 1015, 2220, 1135, 967, 1311, 1310, 1962, 1156, 1144, 1207, 688, 2100, 1772, 1361, 1472, 1086, 1455, 1402, 807]
# [4442, 7567, 7690, 7927, 7461, 7523, 7626, 7687, 7097, 7573, 7404, 7313, 7232, 7196, 7483, 7728, 7332, 7417, 7365, 7862, 8084, 7833, 7842, 7415, 7806, 7929, 8070, 8055, 8019, 7397, 8010, 7761, 7780, 8001, 7692, 7621, 8867, 7741, 7501, 7957, 7956, 8608, 7762, 7750, 7813, 7515, 8747, 8418, 8008, 8119, 7913, 8102, 8049, 6767]
# [2329, 5454, 5577, 5814, 5348, 5410, 5513, 5574, 4984, 5460, 5291, 5200, 5119, 5083, 5370, 5615, 5219, 5304, 5251, 5749, 5971, 5720, 5729, 5302, 5693, 5816, 5957, 5942, 5906, 5284, 5897, 5648, 5667, 5888, 5579, 5508, 6754, 5628, 5388, 5844, 5843, 6495, 5649, 5637, 5700, 5402, 6634, 6305, 5895, 6006, 5800, 5989, 5936, 4654]
# [3729, 1939, 2062, 2407, 1941, 2003, 2114, 1996, 1766, 2053, 1516, 1426, 1344, 1152, 1503, 2032, 1432, 1540, 1275, 1959, 1913, 1623, 1550, 1271, 1506, 1647, 1592, 1578, 1720, 959, 1532, 1283, 1302, 1499, 1214, 1143, 2240, 1263, 1108, 1243, 1242, 1981, 1284, 1272, 1335, 1053, 2120, 1791, 1381, 1478, 975, 1475, 1386, 1289]

# %%
full_duration_matrix[0][0]
# Out:
# 3341

# %%
areas_pobladas_por_region[13]
# Out:
#      objectid_x           comuna  st_area_sh_x  st_length__x  \
# 103       729.0         Santiago  3.337928e+07  29174.519715
# 104       812.0         Santiago  2.925141e+04    802.510895
# 234       837.0         Conchalí  1.581483e+07  16844.836786
# 243       355.0           Tiltil  3.752916e+06   8852.660368
# 244       382.0           Tiltil  1.838870e+06  12522.748140
# ..          ...              ...           ...           ...
# 550       833.0        Lo Espejo  1.173849e+07  13738.858721
# 564       386.0  Calera de Tango  1.635336e+06   9109.965656
# 604       774.0            Alhué  1.899251e+06   8977.461539
# 610       773.0        San Pedro  2.898929e+05   3651.584395
# 616       810.0        Quilicura  3.513244e+07  58053.973468
#
#               Localidad Entidad  \
# 103            Santiago  Ciudad
# 104            Santiago  Ciudad
# 234            Conchalí  Ciudad
# 243  Huertos Familiares  Pueblo
# 244              Tiltil  Pueblo
# ..                  ...     ...
# 550           Lo Espejo  Ciudad
# 564     Calera de Tango  Pueblo
# 604         Villa Alhué   Aldea
# 610           San Pedro   Aldea
# 616           Quilicura  Ciudad
#
#                                             geometry_x  \
# 103  POLYGON ((-70.69185 -33.44449, -70.69165 -33.4...
# 104  POLYGON ((-70.76668 -33.42597, -70.76686 -33.4...
# 234  POLYGON ((-70.68193 -33.40302, -70.68252 -33.4...
# 243  POLYGON ((-70.79690 -33.15114, -70.81196 -33.1...
# 244  POLYGON ((-70.91847 -33.09039, -70.91922 -33.0...
# ..                                                 ...
# 550  POLYGON ((-70.70607 -33.52447, -70.70600 -33.5...
# 564  POLYGON ((-70.77866 -33.62840, -70.77872 -33.6...
# 604  POLYGON ((-71.10990 -34.03613, -71.10942 -34.0...
# 610  POLYGON ((-71.44808 -33.89998, -71.45192 -33.8...
# 616  POLYGON ((-70.77879 -33.36832, -70.76765 -33.3...
#
#                        centroide        lat       long  ...     shape_leng  \
# 103  POINT (-70.65655 -33.45353) -33.453529 -70.656551  ...   24644.018619
# 104  POINT (-70.76793 -33.42621) -33.426211 -70.767934  ...   24644.018619
# 234  POINT (-70.67662 -33.38351) -33.383513 -70.676621  ...   13816.634389
# 243  POINT (-70.80054 -33.13721) -33.137212 -70.800535  ...  133827.265443
# 244  POINT (-70.92607 -33.08503) -33.085031 -70.926073  ...  133827.265443
# ..                           ...        ...        ...  ...            ...
# 550  POINT (-70.68982 -33.52036) -33.520359 -70.689825  ...   11405.976039
# 564  POINT (-70.76949 -33.62956) -33.629563 -70.769485  ...   44852.016431
# 604  POINT (-71.09918 -34.03394) -34.033941 -71.099176  ...  154307.594364
# 610  POINT (-71.45379 -33.89598) -33.895976 -71.453793  ...  162648.311900
# 616  POINT (-70.72965 -33.35887) -33.358869 -70.729648  ...   35236.920632
#
#      dis_elec  cir_sena  cod_comuna  código_región  st_area_sh_y  \
# 103      10.0       7.0     13101.0           13.0  3.337678e+07
# 104      10.0       7.0     13101.0           13.0  3.337678e+07
# 234       9.0       7.0     13104.0           13.0  1.580267e+07
# 243       8.0       7.0     13303.0           13.0  9.324996e+08
# 244       8.0       7.0     13303.0           13.0  9.324996e+08
# ..        ...       ...         ...            ...           ...
# 550      13.0       7.0     13116.0           13.0  1.180479e+07
# 564      14.0       7.0     13403.0           13.0  1.056188e+08
# 604      14.0       7.0     13502.0           13.0  1.232470e+09
# 610      14.0       7.0     13505.0           13.0  1.145316e+09
# 616       8.0       7.0     13125.0           13.0  8.152802e+07
#
#       st_length__y                     nombre_región  Provincia  \
# 103   29171.609500  Región Metropolitana de Santiago   Santiago
# 104   29171.609500  Región Metropolitana de Santiago   Santiago
# 234   16624.358268  Región Metropolitana de Santiago   Santiago
# 243  160053.560383  Región Metropolitana de Santiago  Chacabuco
# 244  160053.560383  Región Metropolitana de Santiago  Chacabuco
# ..             ...                               ...        ...
# 550   13685.618077  Región Metropolitana de Santiago   Santiago
# 564   54017.559247  Región Metropolitana de Santiago      Maipo
# 604  186225.848908  Región Metropolitana de Santiago  Melipilla
# 610  195465.251120  Región Metropolitana de Santiago  Melipilla
# 616   42127.320314  Región Metropolitana de Santiago   Santiago
#
#                                             geometry_y
# 103  POLYGON ((-7864917.074 -3952801.626, -7864220....
# 104  POLYGON ((-7864917.074 -3952801.626, -7864220....
# 234  POLYGON ((-7866184.246 -3948416.404, -7866280....
# 243  POLYGON ((-7873736.745 -3885505.642, -7873695....
# 244  POLYGON ((-7873736.745 -3885505.642, -7873695....
# ..                                                 ...
# 550  POLYGON ((-7869631.801 -3962184.901, -7869473....
# 564  POLYGON ((-7877355.549 -3971828.617, -7877326....
# 604  POLYGON ((-7904570.428 -4014358.626, -7904552....
# 610  POLYGON ((-7966377.354 -4027124.547, -7966377....
# 616  POLYGON ((-7869810.545 -3946247.282, -7869841....
#
# [83 rows x 21 columns]

# %%
import numpy as np
from scipy.spatial import Voronoi
import plotly.graph_objects as go
import geopandas as gpd

# Assuming `areas_pobladas_por_region[13]` is the cities GeoDataFrame
# Assuming `centros_de_salud_por_region[13]['Alta Complejidad']` is the hospitals DataFrame
# Assuming the cities GeoDataFrame has 'geometry' column
# Assuming the hospitals DataFrame has 'geometry' column
# Assuming `full_duration_matrix` is your precomputed travel time matrix in seconds

# Extract city geometries
city_geometries = areas_pobladas_por_region[13]['centroide']
# Add a column to distinguish between cities and hospitals
areas_pobladas_por_region[13].loc[:, 'type'] = 'City'

# Extract hospital geometries
hospital_geometries = centros_de_salud_por_region[13]['Alta Complejidad']['geometry']
# Add a column to distinguish between cities and hospitals
centros_de_salud_por_region[13]['Alta Complejidad'].loc[:, 'type'] = 'Hospital'


# Create GeoDataFrames for cities and hospitals
cities_gdf = gpd.GeoDataFrame(geometry=city_geometries)
cities_gdf['type'] = 'City'

hospitals_gdf = gpd.GeoDataFrame(geometry=hospital_geometries)
hospitals_gdf['type'] = 'Hospital'

# Combine GeoDataFrames using the append method
combined_gdf = pd.concat([cities_gdf, hospitals_gdf], ignore_index=True)

import numpy as np
from scipy.spatial import Voronoi
import plotly.graph_objects as go
import geopandas as gpd

# Assuming `combined_gdf` is the GeoDataFrame with cities, hospitals, and cluster labels
# Assuming `full_duration_matrix` is your precomputed travel time matrix in seconds

# Extract coordinates for Voronoi diagram
coordinates_for_voronoi = combined_gdf['geometry'].apply(lambda geom: (geom.x, geom.y)).values

# Compute Voronoi diagram
vor = Voronoi(coordinates_for_voronoi)

# Create a plotly figure for the Voronoi diagram
fig = go.Figure()

# Plot Voronoi polygons
for region in vor.regions:
    if not -1 in region and len(region) > 0:
        x, y = zip(*[vor.vertices[i] for i in region])
        x = np.array(x)
        y = np.array(y)
        fig.add_trace(go.Scatter(x=np.append(x, x[0]), y=np.append(y, y[0]), mode='lines', fill='toself', line=dict(color='gray', width=2)))

# Plot cities and hospitals separately with different markers
for cluster_label in np.unique(combined_gdf['cluster']):
    cluster_points = combined_gdf[combined_gdf['cluster'] == cluster_label]
    color = plt.cm.tab20(cluster_label / len(np.unique(combined_gdf['cluster'])))
    fig.add_trace(go.Scatter(x=cluster_points['geometry'].x, y=cluster_points['geometry'].y, mode='markers',
                             marker=dict(size=10, color=color), name=f'Cluster {cluster_label}'))

# Show plot
fig.show()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 721
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\2272209923.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   areas_pobladas_por_region[13].loc[:, 'type'] = 'City'
# C:\Users\56961\AppData\Local\Temp\ipykernel_23620\2272209923.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   centros_de_salud_por_region[13]['Alta Complejidad'].loc[:, 'type'] = 'Hospital'
